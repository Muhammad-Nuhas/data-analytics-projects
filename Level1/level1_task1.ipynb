# %%
import pandas as pd
df=pd.read_csv('D:/vs code1/internship/Dataset .csv')
df

# %%
top3_cuisine_counts=df['Cuisines'].value_counts().head(3)
top3_cuisine_counts
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
total_restaurants=len(df)
percentage=(top3_cuisine_counts/total_restaurants)*100
percentage
# Out:
# Cuisines
# North Indian             9.800021
# North Indian, Chinese    5.350225
# Chinese                  3.706418
# Name: count, dtype: float64
